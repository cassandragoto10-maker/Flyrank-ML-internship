# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cassandragoto10-maker/Flyrank-ML-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
workbook.import os, subprocess

if not os.path.isdir("Flyrank-ML-internship"):
subprocess.run([
"git",
"clone",
"https://github.com/cassandragoto10-maker/Flyrank-ML-internship.git"
], check=True)

os.chdir("Flyrank-ML-internship")

print("Current directory:", os.getcwd())
# Out:
#   File "/tmp/ipykernel_1325/4004072728.py", line 1
#     workbook.import os, subprocess
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
#
# The Content Refresh lane can be framed as a classification problem. The goal is to identify content pages that are likely to be declining in performance and should be prioritized for refresh. The model examines page-level features such as impressions, click-through rate, average position, engagement metrics, search volume, and content characteristics to determine whether a page is at risk of decline.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
# Target or Proxy
#
# The target variable is the content trend outcome. A practical target is whether a page is declining in performance. This can be represented using the trend_direction field, where pages marked as "down" are considered to need refresh attention and other pages are considered healthy. This target acts as a proxy for identifying content that should be reviewed and updated.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
#
# The primary success metric is Precision@50. This measures how many of the top 50 pages recommended by the model are actually declining. Precision@50 is appropriate because content teams can only refresh a limited number of pages at a time, making accurate prioritization more valuable than reviewing every page.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import os

for root, dirs, files in os.walk("."):
    if "content_refresh_anonymized.csv" in files:
            print(os.path.join(root, "content_refresh_anonymized.csv"))

# %% [markdown]
# Unit of Analysis
#
# The unit of analysis is a single content page. Each row in the dataset represents one page and contains information about search performance, content attributes, engagement metrics, and trend indicators. The model makes predictions at the page level.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# A fixed rule may focus on only one or two variables, such as traffic decline or search volume. However, content performance depends on many interacting factors including click-through rate, impressions, ranking position, engagement, content type, and search competition. Machine learning can learn patterns across all of these variables simultaneously and identify declining pages more accurately than a simple hand-written rule. This was demonstrated in Week 1, where the random forest model significantly outperformed the baseline rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
